# %% [markdown]
# #**Task1: Language Translator tool**

# %% [markdown]
# Install Translation Library

# %%
# !pip install googletrans==4.0.0-rc1

# %% [markdown]
# #Language codes
#
# for hindi = hi
# for odia = or
# for french = fr
# for spanish = es
# for german = de
# for japanese = ja

# %%
from googletrans import Translator

# create translator object
translator = Translator()

# user input
text = input("Enter text to translate: ")
target = input("Enter target language code (hi, or, fr, es, de, ja): ")

# translate
translated = translator.translate(text, dest=target)

print("Translated Text:", translated.text)
# Out:
# Enter text to translate: hii! how are u ankita?
# Enter target language code (hi, or, fr, es, de, ja): hi
# Translated Text: नमस्ते!कैसी हो अंकिता?

# %% [markdown]
# #**THANK YOU**
# Done by Biswaini chhatoi
